# %% [markdown]
# <a href="https://colab.research.google.com/github/notthatlibrarian/LJ-python-assignment/blob/main/Week_1_Homework_LT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1 Homework
#
# (Be sure to save this to Drive before starting)
#
# For this week we are going to practice requesting information from an API and manipulating it as JSON and as a Dataframe.
#
# We are going to keep working with Collection Builder. Head over to the [Collection Builder Example Projects](https://collectionbuilder.github.io/cb-examples/browse.html) listing and find a site that interests you. Spend some time browsing the website to get acquainted with its contents before proceeding with the questions.

# %%
#The Libraries we will need
import requests
import json
import pandas as pd
from random import randrange

# %%
# @markdown **H1** Find the URL of for the  _metadata.json_ of your selected site and paste it in here.
json_cb_url = "https://cdil.lib.uidaho.edu/keeping-watch/assets/data/metadata.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_url)
#all of the data from the sites
total_cb_data = response_cb.json()
#just the 'objects' indexed in the site
objects_cb_data = total_cb_data['objects']
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# **H2** Run the 'show random cell' a few times to get a sense of what kind of data is in your chosen site.

# %%
#Run this a few times to see random entries in the JSON data that you retrieved.
random_entry = randrange(len(objects_cb_data))
print(json.dumps(objects_cb_data[random_entry],indent=2))
# Out:
# {
#   "objectid": "war-eagle003",
#   "parentid": "war-eagle",
#   "filename": "koda.JPG",
#   "title": "Mark Schreiter's Great Pyrenees dogs",
#   "date": "2021-08-20",
#   "description": "White stones left at War Eagle in rememberance of Mark Schreiter's Great Pyrenees dogs",
#   "subject": "McCall; Central Idaho; Payette National Forest; R-6; Staffed Lookouts; Lookout dogs",
#   "location": "Payette National Forest",
#   "latitude": "45.32173",
#   "longitude": "-115.79478",
#   "type": "image;stillimage",
#   "format": "image/jpeg",
#   "language": "eng",
#   "display_template": "image",
#   "object_location": "https://cdil.lib.uidaho.edu/keeping-watch/objects/koda.JPG",
#   "image_small": "https://cdil.lib.uidaho.edu/keeping-watch/objects/small/koda_sm.jpg",
#   "image_thumb": "https://cdil.lib.uidaho.edu/keeping-watch/objects/thumbs/koda_th.jpg",
#   "object_thumb": "https://cdil.lib.uidaho.edu/keeping-watch/objects/thumbs/koda_th.jpg",
#   "reference_url": "https://cdil.lib.uidaho.edu/keeping-watch/items/war-eagle.html#war-eagle003"
# }

# %% [markdown]
# ## Different Fields!
#
# You can create any number of datafields and correpsonding values for those fields with a Collection Builder site. So the results from the output from the cell above will probably have wildly different results from [my site](https://elibtronic.github.io/AIL_Database/data.html) that we worked on in the Workalong notebook.
#
#
# You can see all of these options from grabbing the _facets.json_ URL from a collection builder homepage. Find that URL for your selected site for **H3**

# %%
# @markdown **H3** Find the URL of the facets.json for your selected site and paste it in here.
json_cb_facets_url = "https://cdil.lib.uidaho.edu/keeping-watch/assets/data/facets.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_facets_url)
#all of the data from the sites
total_facet_data = response_cb.json()
#just the 'objects' indexed in the site
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# Run the cell below to see what the facets used for this site:

# %%
print(json.dumps(total_facet_data,indent=2))
# Out:
# {
#   "facets": [
#     {
#       "field": "subject",
#       "terms": {
#         "staffed lookouts": 43,
#         "r-6": 35,
#         "forest service": 28,
#         "frank church river of no return wilderness": 28,
#         "l-4": 25,
#         "selway-bitterroot wilderness": 18,
#         "volunteer lookouts": 17,
#         "systematic observation": 14,
#         "smoke": 13,
#         "osborne fire finder": 13,
#         "selway river": 12,
#         "magruder corridor": 12,
#         "mccall": 11,
#         "idaho department of lands": 10,
#         "sundance fire": 10,
#         "priest lake": 10,
#         "selkirk mountains": 10,
#         "abandoned lookouts": 9,
#         "seen area": 9,
#         "powell ranger station": 9,
#         "range": 8,
#         "township": 8,
#         "st. mary's peak": 7,
#         "nez-perce clearwater national forest": 7,
#         "salmon river": 7,
#         "osbourne fire finder": 7,
#         "ruffneck peak": 7,
#         "rotating sight ring": 7,
#         "mc-39": 6,
#         "norman mcclain": 6,
#         "bill moore": 6,
#         "diablo peak": 6,
#         "payette national forest": 6,
#         "clearwater river": 6,
#         "lochsa river": 6,
#         "horse hair sight": 6,
#         "accessible": 5,
#         "central idaho": 5,
#         "stanley": 5,
#         "dixie jumbo fire": 5,
#         "chicken peak": 5,
#         "richard holm": 5,
#         "lookout preservation": 5,
#         "cold mountain": 5,
#         "environmentalism": 5,
#         "green revolution": 5,
#         "aerial photography": 5,
#         "idaho": 5,
#         "fire finder": 5,
#         "hell's half acre": 5,
#         "tukudika": 5,
#         "sheepeater mountain": 5,
#         "lightning storms": 5,
#         "salmon-challis national forest": 4,
#         "lightning": 4,
#         "blow-up": 4,
#         "lookout remains": 4,
#         "mcconnell mountain": 4,
#         "earthquake activity": 4,
#         "mountains of memory": 4,
#         "patrol points": 4,
#         "man-wife lookouts": 4,
#         "panoramic lookout project": 4,
#         "lookout dogs": 4,
#         "boise mountains": 4,
#         "trinity mountains": 4,
#         "r4-d8": 4,
#         "lynx fire": 3,
#         "salmon river mountains": 3,
#         "cupula roof": 3,
#         "wilderness act of 1964": 3,
#         "ray kresek": 3,
#         "fire lookout museum": 3,
#         "fire lookouts of the inland northwest": 3,
#         "climate change": 3,
#         "bud moore": 3,
#         "gary snyder": 3,
#         "don scheese": 3,
#         "sheep hill": 3,
#         "legitimate smokes": 3,
#         "trigger point": 3,
#         "fire shield": 3,
#         "bitterroot national forest": 3,
#         "aldo leopold": 3,
#         "idaho writer in residence": 2,
#         "timber protection association": 2,
#         "jack kerouac": 2,
#         "naropa institute of zen buddhism": 2,
#         "geist": 2,
#         "bird cage": 2,
#         "american flag": 2,
#         "lightning rods": 2,
#         "anemometer": 2,
#         "cupola roof": 2,
#         "last rain": 2,
#         "lightning stool": 2,
#         "rain guage": 2,
#         "logging activity": 2,
#         "fmo false smokes": 2,
#         "john thorton": 2,
#         "southern idaho": 2,
#         "hatch roof": 2,
#         "cover": 2,
#         "caribou": 2,
#         "eagle creek fire": 2,
#         "mining": 2,
#         "wildflowers": 2,
#         "salmo-priest wilderness area": 2,
#         "preservation": 2,
#         "slope steepness": 2,
#         "slope position": 2,
#         "montana history portal": 2,
#         "no business lookout": 2,
#         "d-6": 2,
#         "aspect": 1,
#         "water dog": 1,
#         "base map": 1,
#         "salmon-river mountains": 1,
#         "milky way galaxy": 1,
#         "eagle creek fire osbourne fire finder": 1,
#         "l-6": 1,
#         "pack train": 1,
#         "probably cause": 1,
#         "lightning stools": 1,
#         "saint maries peak": 1,
#         "r-7": 1,
#         "fire lookout association": 1,
#         "terminator": 1,
#         "a river runs through it": 1,
#         "the wilderness act of 1964": 1,
#         "timber protection agencies": 1,
#         "hail": 1,
#         "false smoke": 1,
#         "strike": 1,
#         "wind vane": 1,
#         "waterdog": 1,
#         "stevenson screen": 1,
#         "beatnicks": 1,
#         "lightning rod": 1,
#         "burn index": 1,
#         "horse hair sights": 1,
#         "probable cause": 1,
#         "inciweb": 1,
#         "false smokes": 1,
#         "azimuth": 1
#       }
#     },
#     {
#       "field": "creator",
#       "terms": {}
#     },
#     {
#       "field": "format",
#       "terms": {
#         "compound_object": 161,
#         "video/mp4": 30,
#         "image/jpeg": 30,
#         "firetower": 17,
#         "video/youtube": 14,
#         "image/png": 3,
#         "image/mp4": 2,
#         "jpg": 1,
#         "application/pdf": 1
#       }
#     }
#   ]
# }

# %% [markdown]
# **H3** Try to read the JSON that is displayed to the screen. What possible facets are there in the the data. Fill them in the markdown list in the cell below. Add as many entries as you need to describe the site

# %% [markdown]
# Facets in my site are:
# - Subject
# - Creator (empty)
# - Format

# %% [markdown]
# **H4** Which facet shows up the most for your selected site? Put your answer in the cell below

# %% [markdown]
# This facet that shows up the most is "compund_object" (format facet), it is used 161 times on my selected site.

# %% [markdown]
# **H5** Turn the site _metadata.json_ data into a dataframe by completing the cell below. Part of it is written for you. You just need to modify line 4.

# %%
#H5

cb_data = pd.read_json(json_cb_url)
cb_normalized = pd.json_normalize(cb_data['objects'])
cb_normalized
# Out:
#                 objectid                   filename  \
# 0    associated-media001    frank_church_plaque.jpg
# 1    associated-media002           steam_donkey.jpg
# 2    associated-media003  dixie_fire_horizontal.jpg
# 3            basin-butte      basin_butte_theta.JPG
# 4         basin-butte001             tower-tour.MP4
# ..                   ...                        ...
# 254            west-fork                        NaN
# 255            whitehawk                        NaN
# 256           wild-horse                        NaN
# 257        williams-peak                        NaN
# 258           zane-point                        NaN
#
#                                                  title        date  \
# 0                   Frank Church Plaque Near Big Creek  2023-02-12
# 1    Jack with an Artifact of Early Mining in the F...  2023-02-12
# 2                        Landscape of Dixie Jumbo Fire  2023-02-12
# 3                                          Basin Butte  2021-06-07
# 4                        Inside of Basin Butte Lookout  2021-06-07
# ..                                                 ...         ...
# 254                                          West Fork         NaN
# 255                                          Whitehawk         NaN
# 256                                         Wild Horse         NaN
# 257                                      Williams Peak         NaN
# 258                                         Zane Point         NaN
#
#                                            description  \
# 0    Plaque remembering Idaho Senator Frank Church ...
# 1    Jack Kredell with a Steam Donkey near Big Cree...
# 2                                                  NaN
# 3    <strong>Built:</strong> 1933 or 1934<br><stron...
# 4            Video of the inside of Basn Butte lookout
# ..                                                 ...
# 254                                                NaN
# 255                                                NaN
# 256                                                NaN
# 257                                                NaN
# 258                                                NaN
#
#                                                subject  \
# 0           Frank Church River of No Return Wilderness
# 1    Frank Church River of No Return Wilderness; mi...
# 2    Frank Church River of No Return Wilderness; mi...
# 3    Stanley; Idaho; Abandoned lookouts; Forest Ser...
# 4    Stanley; Idaho; Abandoned lookouts; Forest Ser...
# ..                                                 ...
# 254                                                NaN
# 255                                                NaN
# 256                                                NaN
# 257                                                NaN
# 258                                                NaN
#
#                                        location               type  \
# 0    Frank Church River of No Return Wilderness   image;stillimage
# 1    Frank Church River of No Return Wilderness   image;stillimage
# 2    Frank Church River of No Return Wilderness   image;stillimage
# 3                                Stanley, Idaho             record
# 4                                Stanley, Idaho  image;MovingImage
# ..                                          ...                ...
# 254                                         NaN             record
# 255                                         NaN             record
# 256                                         NaN             record
# 257                                         NaN             record
# 258                                         NaN             record
#
#               format language display_template  \
# 0         image/jpeg      eng            image
# 1         image/jpeg      eng            image
# 2         image/jpeg      eng            image
# 3          firetower      eng        firetower
# 4          video/mp4      eng            video
# ..               ...      ...              ...
# 254  compound_object      eng            tower
# 255  compound_object      eng            tower
# 256  compound_object      eng            tower
# 257  compound_object      eng            tower
# 258  compound_object      eng            tower
#
#                                        object_location  \
# 0    https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 1    https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 2    https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 3    https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 4    https://cdil.lib.uidaho.edu/keeping-watch/obje...
# ..                                                 ...
# 254
# 255
# 256
# 257
# 258
#
#                                            image_small  \
# 0    https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 1    https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 2    https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 3    https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 4    https://cdil.lib.uidaho.edu/keeping-watch/obje...
# ..                                                 ...
# 254                                                NaN
# 255                                                NaN
# 256                                                NaN
# 257                                                NaN
# 258                                                NaN
#
#                                            image_thumb  \
# 0    https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 1    https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 2    https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 3    https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 4    https://cdil.lib.uidaho.edu/keeping-watch/obje...
# ..                                                 ...
# 254                                                NaN
# 255                                                NaN
# 256                                                NaN
# 257                                                NaN
# 258                                                NaN
#
#                                           object_thumb  \
# 0    https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 1    https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 2    https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 3    https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 4    https://cdil.lib.uidaho.edu/keeping-watch/obje...
# ..                                                 ...
# 254                                                NaN
# 255                                                NaN
# 256                                                NaN
# 257                                                NaN
# 258                                                NaN
#
#                                          reference_url  \
# 0    https://cdil.lib.uidaho.edu/keeping-watch/item...
# 1    https://cdil.lib.uidaho.edu/keeping-watch/item...
# 2    https://cdil.lib.uidaho.edu/keeping-watch/item...
# 3    https://cdil.lib.uidaho.edu/keeping-watch/item...
# 4    https://cdil.lib.uidaho.edu/keeping-watch/item...
# ..                                                 ...
# 254  https://cdil.lib.uidaho.edu/keeping-watch/item...
# 255  https://cdil.lib.uidaho.edu/keeping-watch/item...
# 256  https://cdil.lib.uidaho.edu/keeping-watch/item...
# 257  https://cdil.lib.uidaho.edu/keeping-watch/item...
# 258  https://cdil.lib.uidaho.edu/keeping-watch/item...
#
#                                              narrative  latitude   longitude  \
# 0                                                  NaN       NaN         NaN
# 1                                                  NaN       NaN         NaN
# 2                                                  NaN       NaN         NaN
# 3    Basin Butte Lookout is located in the Salmon-C...  44.33853  -114.97766
# 4                                                  NaN  44.33853  -114.97766
# ..                                                 ...       ...         ...
# 254                                                NaN   48.8324  -116.75128
# 255                                                NaN  44.28744  -115.53073
# 256                                                NaN   43.9272   -114.0847
# 257                                                NaN  45.01861  -115.66289
# 258                                                NaN   47.3029   -116.2817
#
#         parentid
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4    basin-butte
# ..           ...
# 254          NaN
# 255          NaN
# 256          NaN
# 257          NaN
# 258          NaN
#
# [259 rows x 20 columns]

# %%
#Run this a few times to see random entries in your dataframe
cb_normalized.sample(10)
# Out:
#                  objectid                       filename  \
# 149         gardiner-peak                            NaN
# 60    sheepeater-mountain                            NaN
# 242              swanholm                            NaN
# 117            black-mare                            NaN
# 50      roughneck-peak002                  andy_lost.mp4
# 247           tripod-peak                            NaN
# 34    hell-s-half-acre001  patrick_hellshalf_final_1.mp4
# 67       spot-mountain001               moak_final_2.mp4
# 196           osier-ridge                            NaN
# 81   sundance-mountain003                pam_final_3.mp4
#
#                                                  title        date  \
# 149                                      Gardiner Peak         NaN
# 60                                 Sheepeater Mountain         NaN
# 242                                           Swanholm         NaN
# 117                                         Black Mare         NaN
# 50   What is Lost in the Transition Away from the H...  2021-08-23
# 247                                        Tripod Peak         NaN
# 34   Recording Fire Conditions at Hell's Half Acre ...  2021-07-13
# 67                      The Lynx and Eagle Creek Fires  2021-09-25
# 196                                        Osier Ridge         NaN
# 81    Pam Aunan Discusses Her First Lookout Experience  2021-06-19
#
#                                            description  \
# 149                                                NaN
# 60   <strong>Built:</strong> 1934<br><strong>Status...
# 242                                                NaN
# 117                                                NaN
# 50   Andy Baca discusses what is lost as the Forest...
# 247                                                NaN
# 34   Video of Patrick McMarron recording fire condi...
# 67   Rhett Moak discusses calling in the Lynx Fire ...
# 196                                                NaN
# 81   Pam Aunan discusses her first experience on a ...
#
#                                                subject  \
# 149                                                NaN
# 60                                                 NaN
# 242                                                NaN
# 117                                                NaN
# 50   Earthquake Activity; Terminator; A River Runs ...
# 247                                                NaN
# 34   Magruder Corridor; Selway River; Selway-Bitter...
# 67   Lynx Fire; Osbourne Fire Finder; Staffed Looko...
# 196                                                NaN
# 81   L-4; Priest Lake; Selkirk Mountains; Volunteer...
#
#                                        location               type  \
# 149                                         NaN             record
# 60   Frank Church River of No Return Wilderness             record
# 242                                         NaN             record
# 117                                         NaN             record
# 50   Frank Church River of No Return Wilderness  image;MovingImage
# 247                                         NaN             record
# 34                           Magruder Corridor   image;MovingImage
# 67                            Magruder Corridor  image;MovingImage
# 196                                         NaN             record
# 81                                  Priest Lake  image;MovingImage
#
#               format language display_template  \
# 149  compound_object      eng            tower
# 60         firetower      eng        firetower
# 242  compound_object      eng            tower
# 117  compound_object      eng            tower
# 50         video/mp4      eng            video
# 247  compound_object      eng            tower
# 34         video/mp4      eng            video
# 67         video/mp4      eng            video
# 196  compound_object      eng            tower
# 81         video/mp4      eng            video
#
#                                        object_location  \
# 149
# 60   https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 242
# 117
# 50   https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 247
# 34   https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 67   https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 196
# 81   https://cdil.lib.uidaho.edu/keeping-watch/obje...
#
#                                            image_small  \
# 149                                                NaN
# 60   https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 242                                                NaN
# 117                                                NaN
# 50   https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 247                                                NaN
# 34   https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 67   https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 196                                                NaN
# 81   https://cdil.lib.uidaho.edu/keeping-watch/obje...
#
#                                            image_thumb  \
# 149                                                NaN
# 60   https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 242                                                NaN
# 117                                                NaN
# 50   https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 247                                                NaN
# 34   https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 67   https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 196                                                NaN
# 81   https://cdil.lib.uidaho.edu/keeping-watch/obje...
#
#                                           object_thumb  \
# 149                                                NaN
# 60   https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 242                                                NaN
# 117                                                NaN
# 50   https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 247                                                NaN
# 34   https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 67   https://cdil.lib.uidaho.edu/keeping-watch/obje...
# 196                                                NaN
# 81   https://cdil.lib.uidaho.edu/keeping-watch/obje...
#
#                                          reference_url  \
# 149  https://cdil.lib.uidaho.edu/keeping-watch/item...
# 60   https://cdil.lib.uidaho.edu/keeping-watch/item...
# 242  https://cdil.lib.uidaho.edu/keeping-watch/item...
# 117  https://cdil.lib.uidaho.edu/keeping-watch/item...
# 50   https://cdil.lib.uidaho.edu/keeping-watch/item...
# 247  https://cdil.lib.uidaho.edu/keeping-watch/item...
# 34   https://cdil.lib.uidaho.edu/keeping-watch/item...
# 67   https://cdil.lib.uidaho.edu/keeping-watch/item...
# 196  https://cdil.lib.uidaho.edu/keeping-watch/item...
# 81   https://cdil.lib.uidaho.edu/keeping-watch/item...
#
#                                              narrative     latitude  \
# 149                                                NaN     45.96995
# 60   Sheepeater Mountain Lookout is located in the ...     45.38986
# 242                                                NaN   43.8926667
# 117                                                NaN   44.8201333
# 50                                                 NaN  44.48270554
# 247                                                NaN     44.38412
# 34                                                 NaN     45.64579
# 67                                                 NaN     45.78728
# 196                                                NaN     46.82736
# 81                                                 NaN     48.49076
#
#         longitude           parentid
# 149    -114.76655                NaN
# 60     -115.34687                NaN
# 242  -115.3259667                NaN
# 117     -115.7892                NaN
# 50    -115.155742     roughneck-peak
# 247    -116.12831                NaN
# 34     -114.62838   hell-s-half-acre
# 67     -114.85466      spot-mountain
# 196     -115.0155                NaN
# 81     -116.75149  sundance-mountain

# %% [markdown]
# **H6** This is for bonus!
# Try to write a pandas statement that will display your answer from **H4**. There are plenty of ways to do this, so feel free to use your imagination. What I have started for you here might not work, so feel free to change it as needed.

# %%
cb_normalized[cb_normalized["format"] == "compound_object"].count()
# Out:
# objectid            161
# filename              0
# title               161
# date                  0
# description           0
# subject               0
# location              0
# type                161
# format              161
# language            161
# display_template    161
# object_location     161
# image_small           0
# image_thumb           0
# object_thumb          0
# reference_url       161
# narrative             0
# latitude            160
# longitude           160
# parentid              0
# dtype: int64

# %% [markdown]
# ## All Done!
#
# Congrats you are finished with this week's work. First save as PDF so that you can upload to the Course site then click the `Share` button above and enter `libraryjuicepresspython@gmail.com` so I can get a shared copy of your work.
